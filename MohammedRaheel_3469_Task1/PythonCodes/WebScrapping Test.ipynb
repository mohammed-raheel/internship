# %%
import requests
import bs4

# %%
url = 'http://localhost:8888/view/Downloads/babynamescopy/baby1990.html'
s = requests.Session()
resp = s.get(url,headers={'Authorization': 'token b64468aebcb4b9bd7b8e2ff55b7345b59f37c91f4084d1a5'})
print('Learn code response status: ',resp.status_code)
#print(resp.text)
soup = bs4.BeautifulSoup(resp.text, 'lxml')
# Out:
# Learn code response status:  200

# %%
resp.content
# Out:
# b'<!DOCTYPE HTML>\n<html>\n\n<head>\n  <meta charset="utf-8">\n  <title>baby1990.html</title>\n  <meta name="viewport" content="width=device-width, initial-scale=1.0">\n</head>\n\n<body>\n  <style type="text/css">\n    html, body, #container {\n      height: 100%;\n    }\n    body, #container {\n      overflow: hidden;\n      margin: 0;\n    }\n    #iframe {\n      width: 100%;\n      height: 100%;\n      border: none;\n    }\n  </style>\n  <div id="container">\n    <iframe id="iframe" sandbox="allow-scripts" src="/files/Downloads/babynamescopy/baby1990.html"></iframe>\n  </div>\n</body>\n\n</html>'

# %%
x = soup.select('iframe')
x[0]['src'][1:]
# Out:
# 'files/Downloads/babynamescopy/baby1990.html'

# %%
link2 = 'http://localhost:8888/' + x[0]['src'][1:]
print(link2)
resp2 = s.get(link2,headers={'Authorization': 'token b64468aebcb4b9bd7b8e2ff55b7345b59f37c91f4084d1a5'})
# Out:
# http://localhost:8888/files/Downloads/babynamescopy/baby1990.html

# %%
resp2.content
# Out:
# b'<head><title>Popular Baby Names</title>\n<meta name="dc.language" scheme="ISO639-2" content="eng">\n<meta name="dc.creator" content="OACT">\n<meta name="lead_content_manager" content="JeffK">\n<meta name="coder" content="JeffK">\n<meta name="dc.date.reviewed" scheme="ISO8601" content="2005-12-30">\n<link rel="stylesheet" href="../OACT/templatefiles/master.css" type="text/css" media="screen">\n<link rel="stylesheet" href="../OACT/templatefiles/custom.css" type="text/css" media="screen">\n<link rel="stylesheet" href="../OACT/templatefiles/print.css" type="text/css" media="print">\n</head>\n<body bgcolor="#ffffff" text="#000000" topmargin="1" leftmargin="0">\n<table width="100%" border="0" cellspacing="0" cellpadding="4">\n  <tbody>\n  <tr><td class="sstop" valign="bottom" align="left" width="25%">\n      Social Security Online\n    </td><td valign="bottom" class="titletext">\n      <!-- sitetitle -->Popular Baby Names\n    </td>\n  </tr>\n  <tr bgcolor="#333366"><td colspan="2" heigh
# ...

# %%
soup2 = bs4.BeautifulSoup(resp2.text,'lxml')
name_rank = soup2.find_all('h3')
sub_title = name_rank[0].text
print('Sub Title: ',sub_title)
# Out:
# Sub Title:  Popularity in 1990

# %%
# Get the correct table
table = soup2.find('table',summary="Popularity for top 1000")
print(table)
# Out:
# <table border="1" bordercolor="#aaabbb" cellpadding="2" cellspacing="0" summary="Popularity for top 1000" width="48%">
# <tr align="center" valign="bottom">
# <th bgcolor="#efefef" scope="col" width="12%">Rank</th>
# <th bgcolor="#99ccff" scope="col" width="41%">Male name</th>
# <th bgcolor="pink" scope="col" width="41%">Female name</th></tr>
# <tr align="right"><td>1</td><td>Michael</td><td>Jessica</td>
# </tr><tr align="right"><td>2</td><td>Christopher</td><td>Ashley</td>
# </tr><tr align="right"><td>3</td><td>Matthew</td><td>Brittany</td>
# </tr><tr align="right"><td>4</td><td>Joshua</td><td>Amanda</td>
# </tr><tr align="right"><td>5</td><td>Daniel</td><td>Samantha</td>
# </tr><tr align="right"><td>6</td><td>David</td><td>Sarah</td>
# </tr><tr align="right"><td>7</td><td>Andrew</td><td>Stephanie</td>
# </tr><tr align="right"><td>8</td><td>James</td><td>Jennifer</td>
# </tr><tr align="right"><td>9</td><td>Justin</td><td>Elizabeth</td>
# ...

# %%
tabRows = table.find_all('tr',{'align':'right'})
len(tabRows)
tabRows
# Out:
# [<tr align="right"><td>1</td><td>Michael</td><td>Jessica</td>
#  </tr>, <tr align="right"><td>2</td><td>Christopher</td><td>Ashley</td>
#  </tr>, <tr align="right"><td>3</td><td>Matthew</td><td>Brittany</td>
#  </tr>, <tr align="right"><td>4</td><td>Joshua</td><td>Amanda</td>
#  </tr>, <tr align="right"><td>5</td><td>Daniel</td><td>Samantha</td>
#  </tr>, <tr align="right"><td>6</td><td>David</td><td>Sarah</td>
#  </tr>, <tr align="right"><td>7</td><td>Andrew</td><td>Stephanie</td>
#  </tr>, <tr align="right"><td>8</td><td>James</td><td>Jennifer</td>
#  </tr>, <tr align="right"><td>9</td><td>Justin</td><td>Elizabeth</td>
#  </tr>, <tr align="right"><td>10</td><td>Joseph</td><td>Lauren</td>
#  </tr>, <tr align="right"><td>11</td><td>Ryan</td><td>Megan</td>
#  </tr>, <tr align="right"><td>12</td><td>John</td><td>Emily</td>
#  </tr>, <tr align="right"><td>13</td><td>Robert</td><td>Nicole</td>
#  </tr>, <tr align="right"><td>14</td><td>Nicholas</td><td>Kayla</td>
# ...

# %%
# Use regular expression to extract information

# %%
import re

# %%
lstNameRank = []
for i in tabRows:
    #print(str(i))
    vals = re.findall(r'<td>(\w+)</td><td>(\w+)</td><td>(\w+)</td>',str(i))
    lstNameRank.extend(vals)
    
print(lstNameRank)
# Out:
# [('1', 'Michael', 'Jessica'), ('2', 'Christopher', 'Ashley'), ('3', 'Matthew', 'Brittany'), ('4', 'Joshua', 'Amanda'), ('5', 'Daniel', 'Samantha'), ('6', 'David', 'Sarah'), ('7', 'Andrew', 'Stephanie'), ('8', 'James', 'Jennifer'), ('9', 'Justin', 'Elizabeth'), ('10', 'Joseph', 'Lauren'), ('11', 'Ryan', 'Megan'), ('12', 'John', 'Emily'), ('13', 'Robert', 'Nicole'), ('14', 'Nicholas', 'Kayla'), ('15', 'Anthony', 'Amber'), ('16', 'William', 'Rachel'), ('17', 'Jonathan', 'Courtney'), ('18', 'Kyle', 'Danielle'), ('19', 'Brandon', 'Heather'), ('20', 'Jacob', 'Melissa'), ('21', 'Tyler', 'Rebecca'), ('22', 'Zachary', 'Michelle'), ('23', 'Kevin', 'Tiffany'), ('24', 'Eric', 'Chelsea'), ('25', 'Steven', 'Christina'), ('26', 'Thomas', 'Katherine'), ('27', 'Brian', 'Alyssa'), ('28', 'Alexander', 'Jasmine'), ('29', 'Jordan', 'Laura'), ('30', 'Timothy', 'Hannah'), ('31', 'Cody', 'Kimberly'), ('32', 'Adam', 'Kelsey'), ('33', 'Benjamin', 'Victoria'), ('34', 'Aaron', 'Sara'), ('35', 'Richard', 'Mary')
# ...

# %%
# Create a dictionary
baby_name = dict()

# %%
# Now insert name and ranks in the dictionary
counter = 0
duplicateName = []
for i in lstNameRank:
    rank = i[0]
    boyName = i[1]
    girlName = i[2]
    
    # Check if the boyname already exists
    if boyName in baby_name and int(baby_name[boyName]) < int(rank):
        duplicateName.append(boyName)
    else:
        baby_name[boyName] = rank
        
    if girlName in baby_name and int(baby_name[girlName]) < int(rank):
        duplicateName.append(girlName)
    else:
        baby_name[girlName] = rank
        
    counter+=1
    
print(baby_name)
# Out:
# {'Michael': '1', 'Jessica': '1', 'Christopher': '2', 'Ashley': '2', 'Matthew': '3', 'Brittany': '3', 'Joshua': '4', 'Amanda': '4', 'Daniel': '5', 'Samantha': '5', 'David': '6', 'Sarah': '6', 'Andrew': '7', 'Stephanie': '7', 'James': '8', 'Jennifer': '8', 'Justin': '9', 'Elizabeth': '9', 'Joseph': '10', 'Lauren': '10', 'Ryan': '11', 'Megan': '11', 'John': '12', 'Emily': '12', 'Robert': '13', 'Nicole': '13', 'Nicholas': '14', 'Kayla': '14', 'Anthony': '15', 'Amber': '15', 'William': '16', 'Rachel': '16', 'Jonathan': '17', 'Courtney': '17', 'Kyle': '18', 'Danielle': '18', 'Brandon': '19', 'Heather': '19', 'Jacob': '20', 'Melissa': '20', 'Tyler': '21', 'Rebecca': '21', 'Zachary': '22', 'Michelle': '22', 'Kevin': '23', 'Tiffany': '23', 'Eric': '24', 'Chelsea': '24', 'Steven': '25', 'Christina': '25', 'Thomas': '26', 'Katherine': '26', 'Brian': '27', 'Alyssa': '27', 'Alexander': '28', 'Jasmine': '28', 'Jordan': '29', 'Laura': '29', 'Timothy': '30', 'Hannah': '30', 'Cody': '31', 'Kimberly':
# ...

# %%
len(baby_name.keys())
# Out:
# 1919

# %%
print(counter)
# Out:
# 1000

# %%
len(duplicateName)
# Out:
# 81

# %%
# Sort keys alphabetically

# %%
sortedVals = dict()
for i in sorted(baby_name.keys()):
    sortedVals[i] = baby_name[i]

# %%
print(baby_name)
# Out:
# {'Michael': '1', 'Jessica': '1', 'Christopher': '2', 'Ashley': '2', 'Matthew': '3', 'Brittany': '3', 'Joshua': '4', 'Amanda': '4', 'Daniel': '5', 'Samantha': '5', 'David': '6', 'Sarah': '6', 'Andrew': '7', 'Stephanie': '7', 'James': '8', 'Jennifer': '8', 'Justin': '9', 'Elizabeth': '9', 'Joseph': '10', 'Lauren': '10', 'Ryan': '11', 'Megan': '11', 'John': '12', 'Emily': '12', 'Robert': '13', 'Nicole': '13', 'Nicholas': '14', 'Kayla': '14', 'Anthony': '15', 'Amber': '15', 'William': '16', 'Rachel': '16', 'Jonathan': '17', 'Courtney': '17', 'Kyle': '18', 'Danielle': '18', 'Brandon': '19', 'Heather': '19', 'Jacob': '20', 'Melissa': '20', 'Tyler': '21', 'Rebecca': '21', 'Zachary': '22', 'Michelle': '22', 'Kevin': '23', 'Tiffany': '23', 'Eric': '24', 'Chelsea': '24', 'Steven': '25', 'Christina': '25', 'Thomas': '26', 'Katherine': '26', 'Brian': '27', 'Alyssa': '27', 'Alexander': '28', 'Jasmine': '28', 'Jordan': '29', 'Laura': '29', 'Timothy': '30', 'Hannah': '30', 'Cody': '31', 'Kimberly':
# ...

# %%
print(sortedVals)
# Out:
# {'Aaron': '34', 'Abbey': '482', 'Abbie': '685', 'Abby': '222', 'Abdul': '934', 'Abel': '384', 'Abigail': '90', 'Abraham': '246', 'Abram': '920', 'Adam': '32', 'Adan': '548', 'Addison': '645', 'Adolfo': '649', 'Adrian': '94', 'Adriana': '144', 'Adrianna': '325', 'Adrianne': '783', 'Adrienne': '233', 'Agustin': '627', 'Ahmad': '562', 'Ahmed': '721', 'Aidan': '889', 'Aileen': '851', 'Aimee': '272', 'Aisha': '568', 'Aja': '940', 'Akeem': '405', 'Alaina': '441', 'Alan': '125', 'Alana': '368', 'Alanna': '474', 'Alannah': '936', 'Albert': '167', 'Alberto': '225', 'Alden': '949', 'Aldo': '792', 'Alec': '271', 'Alecia': '678', 'Alejandra': '211', 'Alejandro': '126', 'Alesha': '695', 'Alessandra': '829', 'Alex': '59', 'Alexa': '146', 'Alexander': '28', 'Alexandra': '37', 'Alexandre': '950', 'Alexandrea': '653', 'Alexandria': '95', 'Alexandro': '837', 'Alexia': '557', 'Alexis': '66', 'Alfonso': '423', 'Alfred': '364', 'Alfredo': '272', 'Ali': '474', 'Alice': '347', 'Alicia': '53', 'Alina': '664
# ...

# %%
print(len(sortedVals))
# Out:
# 1919

# %%
year = '1990'
finalResult = []
finalResult.append(year)
for i in sortedVals:
    finalResult.append(i + ' ' + sortedVals[i])

# %%
print(finalResult)
# Out:
# ['1990', 'Aaron 34', 'Abbey 482', 'Abbie 685', 'Abby 222', 'Abdul 934', 'Abel 384', 'Abigail 90', 'Abraham 246', 'Abram 920', 'Adam 32', 'Adan 548', 'Addison 645', 'Adolfo 649', 'Adrian 94', 'Adriana 144', 'Adrianna 325', 'Adrianne 783', 'Adrienne 233', 'Agustin 627', 'Ahmad 562', 'Ahmed 721', 'Aidan 889', 'Aileen 851', 'Aimee 272', 'Aisha 568', 'Aja 940', 'Akeem 405', 'Alaina 441', 'Alan 125', 'Alana 368', 'Alanna 474', 'Alannah 936', 'Albert 167', 'Alberto 225', 'Alden 949', 'Aldo 792', 'Alec 271', 'Alecia 678', 'Alejandra 211', 'Alejandro 126', 'Alesha 695', 'Alessandra 829', 'Alex 59', 'Alexa 146', 'Alexander 28', 'Alexandra 37', 'Alexandre 950', 'Alexandrea 653', 'Alexandria 95', 'Alexandro 837', 'Alexia 557', 'Alexis 66', 'Alfonso 423', 'Alfred 364', 'Alfredo 272', 'Ali 474', 'Alice 347', 'Alicia 53', 'Alina 664', 'Alisa 460', 'Alisha 135', 'Alison 133', 'Alissa 276', 'Allan 382', 'Allen 141', 'Allie 579', 'Allison 48', 'Allyson 236', 'Allyssa 709', 'Alma 386', 'Alonso 805', 'A
# ...
